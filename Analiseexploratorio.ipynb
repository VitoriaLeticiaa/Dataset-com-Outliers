"Redes de Computadores", "Logística", "Administração", "Redes de Computadores", "Logística", "Administração", "Redes de Computadores", "Logística", "Logística", "Administração", "Redes de Computadores", "Administração", "Logística", "Redes de Computadores", "Administração", "Logística", "Redes de Computadores", "Administração", "Logística", "Logística", "Redes de Computadores", "Administração", "Administração", "Redes de Computadores", "Logística", "Redes de Computadores", "Administração", "Logística", "Redes de Computadores", "Administração", "Logística", "Logística", "Redes de Computadores", "Administração", "Logística", "Redes de Computadores", "Administração", "Logística", "Redes de Computadores", "Administração", "Logística", "Redes de Computadores", "Administração", "Logística", "Redes de Computadores"],
    'Módulo': [2, 1, 3, 2, 1, 3, 2, 3, 1, 2, 1, 2, 1, 3, 2, 3, 1, 2, 2, 3, 1, 1, 2, 3, 2, 3, 1, 2, 1, 3, 2, 3, 1, 2, 3, 2, 1, 3, 1, 2, 3, 1, 2, 2, 3, 1, 2, 1, 3, 1],
    'N° Computador': [27,14,3,38,9,22,5,31,17,40,1,26,12,33,7,19,42,6,11,24,30,8,21,13,35,2,28,16,39,4,10,23,34,15,20,37,25,41,29,36,18,32,27,14,5,22,9,31,7,12],
    }

# %%
agendamento = pd.DataFrame(sistema_agendamento)

# %%
agendamento
# Out:
#              Nome                          E-mail     Telefone  \
# 0           Lucas           lucas.silva@email.com  81992109876
# 1       Ana Clara       ana.clara.souza@email.com  81982109877
# 2         Gabriel      gabriel.oliveira@email.com  81972109888
# 3   Maria Eduarda    maria.eduarda.lima@email.com  81962109887
# 4          Miguel          miguel.costa@email.com  81952109886
# 5           Júlia       julia.fernandes@email.com  81991234567
# 6          Arthur      arthur.rodrigues@email.com  81993456789
# 7         Beatriz         beatriz.gomes@email.com  81994567890
# 8           Pedro         pedro.almeida@email.com  81995678901
# 9         Mariana       mariana.pereira@email.com  81996789012
# 10           João          joao.cardoso@email.com  81997890123
# 11        Larissa       larissa.martins@email.com  81998901234
# 12        Matheus      matheus.teixeira@email.com  81999012345
# 13       Isabella      isabella.freitas@email.com  81987654321
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
agendamento.to_csv('/content/drive/MyDrive/Colab Notebooks/agendamento.csv', index=False)

# %%
import seaborn as se

# %%
import statistics as st

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# /content
# ['.config', 'drive', 'sample_data']

# %%
agedamento : pd.read_csv('/content/drive/MyDrive/Colab Notebooks/agendamento.csv', sep=";")

# %%
agendamento
agendamento.head(50)
agendamento.tail(50)
agendamento.sample(50)
# Out:
#              Nome                          E-mail     Telefone  \
# 49          Tainá            taina.braz@email.com  81996495253
# 40         Nathan         nathan.castro@email.com  81960987654
# 21          Sofia            sofia.dias@email.com  81979876543
# 47         Nicole        nicole.tavares@email.com  81953210987
# 46          Ícaro        icaro.silveira@email.com  81954321098
# 5           Júlia       julia.fernandes@email.com  81991234567
# 26        Eduardo         eduardo.faria@email.com  81974321098
# 27        Vitória     vitoria.bernardes@email.com  81973210987
# 34         Felipe           felipe.reis@email.com  81966543210
# 15         Amanda       amanda.nogueira@email.com  81985432109
# 45          Lívia         livia.esteves@email.com  81955432109
# 22         Thiago        thiago.moreira@email.com  81978765432
# 20          Bruno          bruno.santos@email.com  81980987654
# 2         Gabriel      gabriel.oliveira@email.com  81972109888
# ...

# %%
agendamento.shape
# Out:
# (50, 6)

# %%
agendamento.columns = ["Nome", "E-mail", "Telefone", "Curso", "Módulo", "N° Computador"]

# %%
agendamento.head()
# Out:
#             Nome                        E-mail     Telefone  \
# 0          Lucas         lucas.silva@email.com  81992109876
# 1      Ana Clara     ana.clara.souza@email.com  81982109877
# 2        Gabriel    gabriel.oliveira@email.com  81972109888
# 3  Maria Eduarda  maria.eduarda.lima@email.com  81962109887
# 4         Miguel        miguel.costa@email.com  81952109886
#
#                    Curso  Módulo  N° Computador
# 0  Redes de Computadores       2             27
# 1          Administração       1             14
# 2              Logística       3              3
# 3          Administração       2             38
# 4              Logística       1              9

# %%
email = agendamento.groupby(['E-mail']).size()

# %%
email
# Out:
# E-mail
# amanda.nogueira@email.com         1
# ana.clara.souza@email.com         1
# andre.miranda@email.com           1
# arthur.rodrigues@email.com        1
# beatriz.gomes@email.com           1
# bianca.andrade@email.com          1
# bruna.vieira@email.com            1
# bruno.santos@email.com            1
# caio.amaral@email.com             1
# camila.barros@email.com           1
# daniel.coelho@email.com           1
# diego.lopes@email.com             1
# eduardo.faria@email.com           1
# enzo.lima@email.com               1
# felipe.reis@email.com             1
# fernanda.vasconcelos@email.com    1
# gabriel.oliveira@email.com        1
# giovanna.ferraz@email.com         1
# gustavo.ramos@email.com           1
# heloisa.pinheiro@email.com        1
# henrique.moraes@email.com         1
# icaro.silveira@email.com          1
# isabella.freitas@email.com        1
# joao.cardoso@email.com            1
# julia.fernandes@email.com         1
# larissa.martins@email.com         1
# ...

# %%
email.plot.bar()
# Out:
# <Axes: xlabel='E-mail'>

# %%
curso = agendamento.groupby(['Curso']).size()
curso
# Out:
# Curso
# Administração            16
# Logística                18
# Redes de Computadores    16
# dtype: int64

# %%
agendamento['Módulo'].describe()
# Out:
# count    50.000000
# mean      1.960000
# std       0.807111
# min       1.000000
# 25%       1.000000
# 50%       2.000000
# 75%       3.000000
# max       3.000000
# Name: Módulo, dtype: float64

# %%
se.boxplot(agendamento['Módulo']).set_title('Módulo')
# Out:
# Text(0.5, 1.0, 'Módulo')

# %%
se.histplot(agendamento['Módulo']).set_title('Módulo')
# Out:
# Text(0.5, 1.0, 'Módulo')

# %%
agendamento['N° Computador'].describe()
# Out:
# count    50.000000
# mean     20.600000
# std      11.982981
# min       1.000000
# 25%      10.250000
# 50%      20.500000
# 75%      30.750000
# max      42.000000
# Name: N° Computador, dtype: float64

# %%
se.boxplot(agendamento['N° Computador']).set_title('N° Computador')
# Out:
# Text(0.5, 1.0, 'N° Computador')

# %%
agendamento.isnull().sum()
# Out:
# Nome             0
# E-mail           0
# Telefone         0
# Curso            0
# Módulo           0
# N° Computador    0
# dtype: int64
